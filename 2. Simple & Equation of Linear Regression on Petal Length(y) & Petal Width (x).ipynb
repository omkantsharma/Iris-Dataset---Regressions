# %% [markdown]
# # Iris Data Set

# %% [markdown]
# ### Import the Data

# %%
import pandas as pd  # alias pd

# %%
df = pd.read_csv("c:/Users/omkan/Downloads/om data/Iris.csv")

# %% [markdown]
# Iris dataset source - https://www.kaggle.com/datasets/uciml/iris

# %%
iris = df

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Clean the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.corr(method='pearson')
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#sns.heatmap(df.corr(method='pearson'))
sns.heatmap(df.corr(method='pearson'),annot = True);
plt.show()

# %% [raw]
# From the above graph, we can see that –
#
# Petal width and petal length have high correlations.
# Petal length and sepal width have good correlations.

# %%
sns.set(style="ticks", color_codes=True)
df = sns.load_dataset("iris")
Iris_pairplot=sns.pairplot(df, hue="species", palette="husl")

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',hue='Species',data=iris)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='SepalWidthCm',y='PetalWidthCm',data=iris,hue='Species')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',data=iris,hue='Species')
plt.show()

# %% [raw]
# There is no obvious relation between Sepal.Length and Sepal.Width

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='PetalLengthCm',y='PetalWidthCm',data=iris,hue='Species')
plt.show()

# %% [raw]
# There is a positive relation between Petal.Length and Petal.Width

# %% [markdown]
# ## 2. Simple & Equation of Linear Regression  on Petal Length(y) & Petal Width (x)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()  #use alias

# %% [markdown]
# ###### Clean the Data

# %%
iris.head(2)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
iris.head(2)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
x=iris[['PetalWidthCm']]

# %%
y=iris['PetalLengthCm']

# %%
x.head(2),x.shape,type(x)
# Out:
# (   PetalWidthCm
#  0           0.2
#  1           0.2,
#  (150, 1),
#  pandas.core.frame.DataFrame)

# %%
y.head(2),y.shape,type(y)
# Out:
# (0    1.4
#  1    1.4
#  Name: PetalLengthCm, dtype: float64,
#  (150,),
#  pandas.core.series.Series)

# %% [markdown]
# ###### Split the data into training and test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((105, 1), (45, 1), (105,), (45,))

# %%
x_train.head(2),x_test.head(2),y_train.head(2),y_test.head(2)
# Out:
# (    PetalWidthCm
#  62           1.0
#  48           0.2,
#      PetalWidthCm
#  21           0.4
#  65           1.4,
#  62    4.0
#  48    1.5
#  Name: PetalLengthCm, dtype: float64,
#  21    1.5
#  65    4.4
#  Name: PetalLengthCm, dtype: float64)

# %%
type(x_train),type(x_test),type(y_train),type(y_test)
# Out:
# (pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame,
#  pandas.core.series.Series,
#  pandas.core.series.Series)

# %% [markdown]
# ##### Create the Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr1=lr

# %%
lr1.fit(x_train,y_train)  # fit the algorithem
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
lr1.score(x_train,y_train) # R2 score - goodness of fit on train data set
# Out:
# 0.919438056748541

# %%
lr1.score(x_test,y_test)  # R2 score - goodness of fit on test data set
# Out:
# 0.9417868758128862

# %% [markdown]
# #### Make Prediction

# %%
y_pred1=lr1.predict(x_test)

# %%
y_pred[0:6],type(y_pred1),y_pred1.shape
# Out:
# (array([5.95964052, 5.70624758, 5.8751762 , 5.84139048, 5.82449762,
#         5.63867613]),
#  numpy.ndarray,
#  (45,))

# %%
x_test.head(2),type(x_test)  # X_test dataframe
# Out:
# (    PetalWidthCm
#  21           0.4
#  65           1.4,
#  pandas.core.frame.DataFrame)

# %%
x_test_p=x_test['PetalWidthCm']   # made x_test series
x_test_p.head(2),type(x_test_p)
# Out:
# (21    0.4
#  65    1.4
#  Name: PetalWidthCm, dtype: float64,
#  pandas.core.series.Series)

# %%
# merge x_test_p, y_test,y_pred1 in one dataframe
lr_test_p = pd.DataFrame({'x_test_p':x_test_p,'y_test':y_test, 'y_pred1':y_pred1})
lr_test_p.head(3),lr_test_p.shape,type(lr_test_p)
# Out:
# (    x_test_p  y_test   y_pred1
#  21       0.4     1.5  2.016554
#  65       1.4     4.4  4.215631
#  26       0.4     1.6  2.016554,
#  (45, 3),
#  pandas.core.frame.DataFrame)

# %%
# rename column dt
lr_test_p=pd.DataFrame({'PetalWidth_x_test':x_test_p,'PatalLenth_y_test':y_test,'PatalLenth_y_pred1':y_pred1})
lr_test_p.head(3),lr_test_p.shape,type(lr_test_p)
# Out:
# (    PetalWidth_x_test  PatalLenth_y_test  PatalLenth_y_pred1
#  21                0.4                1.5            2.016554
#  65                1.4                4.4            4.215631
#  26                0.4                1.6            2.016554,
#  (45, 3),
#  pandas.core.frame.DataFrame)

# %%
plt.figure(figsize=(10,2))
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_test',data=lr_test_p)
plt.title("""
PetalWidth_x_test  vs  PatalLenth_y_test""")
plt.show()
plt.figure(figsize=(10,3))
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_test',data=lr_test_p)
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_pred1',data=lr_test_p, hue='PatalLenth_y_pred1')
plt.title("""Simple Linear Regression
PetalWidth_x_test vs PatalLenth_y_pred1 & PatalLenth_y_test""")
plt.show()
plt.figure(figsize=(10,4))
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_test',data=lr_test_p,)
sns.lineplot(x='PetalWidth_x_test',y='PatalLenth_y_pred1',data=lr_test_p,)
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_pred1',data=lr_test_p, hue='PatalLenth_y_pred1')
plt.title("""Simple Linear Regression with line chart
PetalWidth_x_test vs PatalLenth_y_pred1 & PatalLenth_y_test""")
plt.show()

# %% [markdown]
# Matplotlib

# %%
lr_test_p.head(2)
# Out:
#     PetalWidth_x_test  PatalLenth_y_test  PatalLenth_y_pred1
# 21                0.4                1.5            2.016554
# 65                1.4                4.4            4.215631

# %%
plt.figure(figsize=(10,4))
plt.scatter(lr_test_p['PetalWidth_x_test'],lr_test_p['PatalLenth_y_test'], color="red",label='Actual data')
plt.scatter(lr_test_p['PetalWidth_x_test'],lr_test_p['PatalLenth_y_pred1'], color="blue",label='Predicted DATA')
plt.legend()
plt.title("""Simple Linear Regression
PetalWidth_x_test vs PatalLenth_y_predicted data & PatalLenth_y_test""")
plt.xlabel("PetalWidth_x_test")
plt.ylabel("PatalLenth_y_test & PatalLenth_y_pred1")
plt.show()

plt.figure(figsize=(10,4))
plt.scatter(lr_test_p['PetalWidth_x_test'],lr_test_p['PatalLenth_y_test'], color="red",label='Actual data')
plt.plot(lr_test_p['PetalWidth_x_test'],lr_test_p['PatalLenth_y_pred1'], color="blue",label='Predicted Line')
plt.legend()
#plt.title("""Simple Linear Regression
#PetalWidth_x_test vs PatalLenth_y_pred1 & PatalLenth_y_test""")
plt.xlabel("PetalWidth_x_test")
plt.ylabel("PatalLenth_y_test & PatalLenth_y_pred1")
plt.show()

# %% [markdown]
# ###  Equation of Linear Regression

# %% [raw]
# y = ax + b
# y = mx + c
# y (Linear_Regression_pred_equ) = x (Independent Variable)  *  reg.coef_  +       reg.inercpt_
# iris data set for simple linear Regression for y=mx + c
# (or)     y = ax + b

# %% [markdown]
# ### Train the Model

# %%
#m = slope/coeffieient or a
lr1.coef_         # a
# Out:
# array([2.19907769])

# %%
# c = constant/bais/intercept  or b
lr1.intercept_           # b
# Out:
# 1.1369224413229415

# %% [markdown]
# Now use equation of Linear equation

# %% [markdown]
# #### Make Prediction

# %%
PetalLenth_y_equ_p=x_test*lr1.coef_+lr1.intercept_

# %%
PetalLenth_y_equ_p.head(2) # colunm came-PetalWidthCm but predict PetalLenth_y
# Out:
#     PetalWidthCm
# 21      2.016554
# 65      4.215631

# %%
PatalLenth_y_equa_lr=PetalLenth_y_equ_p['PetalWidthCm']

# %%
PatalLenth_y_equa_lr.head(2),PatalLenth_y_equa_lr.shape,type(PatalLenth_y_equa_lr)
# Out:
# (21    2.016554
#  65    4.215631
#  Name: PetalWidthCm, dtype: float64,
#  (45,),
#  pandas.core.series.Series)

# %%
lr_test_p.head(2)
# Out:
#     PetalWidth_x_test  PatalLenth_y_test  PatalLenth_y_pred1
# 21                0.4                1.5            2.016554
# 65                1.4                4.4            4.215631

# %%
  PetalLenth_y_allslr_p =pd.DataFrame({'PetalWidth_x_test':x_test_p,'PatalLenth_y_test':y_test,'PatalLenth_y_pred1':y_pred1,'PatalLenth_y_equa_lr':PatalLenth_y_equa_lr})

# %%
PetalLenth_y_allslr_p.shape,type(PetalLenth_y_allslr_p)
# Out:
# ((45, 4), pandas.core.frame.DataFrame)

# %%
PetalLenth_y_allslr_p.head(2)
# Out:
#     PetalWidth_x_test  PatalLenth_y_test  PatalLenth_y_pred1  \
# 21                0.4                1.5            2.016554
# 65                1.4                4.4            4.215631
#
#     PatalLenth_y_equa_lr
# 21              2.016554
# 65              4.215631

# %%
plt.figure(figsize=(10,1))
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_test',data=PetalLenth_y_allslr_p)
plt.title("""
PetalWidth_x_test  vs  PatalLenth_y_test""")
plt.show()
plt.figure(figsize=(10,1))
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_test',data=PetalLenth_y_allslr_p)
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_pred1',data=PetalLenth_y_allslr_p, hue='PatalLenth_y_pred1')
plt.title("""Simple Linear Regression
PetalWidth_x_test vs PatalLenth_y_pred1 & PatalLenth_y_test""")
plt.show()
plt.figure(figsize=(10,1))
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_test',data=PetalLenth_y_allslr_p,)
sns.lineplot(x='PetalWidth_x_test',y='PatalLenth_y_pred1',data=PetalLenth_y_allslr_p,)
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_pred1',data=PetalLenth_y_allslr_p, hue='PatalLenth_y_pred1')
plt.title("""Simple Linear Regression with line chart
PetalWidth_x_test vs PatalLenth_y_pred1 & PatalLenth_y_test""")
plt.show()
plt.figure(figsize=(10,1))
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_test',data=PetalLenth_y_allslr_p,)
sns.lineplot(x='PetalWidth_x_test',y='PatalLenth_y_equa_lr',data=PetalLenth_y_allslr_p,)
sns.scatterplot(x='PetalWidth_x_test',y='PatalLenth_y_equa_lr',data=PetalLenth_y_allslr_p, hue='PatalLenth_y_equa_lr')
plt.title("""Equation of Linear Regression with line chart
PetalWidth_x_test vs PatalLenth_y_equa_lr & PatalLenth_y_test""")
plt.show()

# %%
PetalLenth_y_allslr_p.head(2)
# Out:
#     PetalWidth_x_test  PatalLenth_y_test  PatalLenth_y_pred1  \
# 21                0.4                1.5            2.016554
# 65                1.4                4.4            4.215631
#
#     PatalLenth_y_equa_lr
# 21              2.016554
# 65              4.215631

# %%
plt.figure(figsize=(10,1))
plt.scatter(PetalLenth_y_allslr_p['PetalWidth_x_test'],lr_test_p['PatalLenth_y_test'], color="red",label='actual data ')
plt.scatter(PetalLenth_y_allslr_p['PetalWidth_x_test'],lr_test_p['PatalLenth_y_pred1'], color="blue",label='Predicted data')
plt.legend()
plt.title("""Simple Linear Regression
PetalWidth_x_test vs PatalLenth_y_prediced data & PatalLenth_y_test""")
plt.xlabel("PetalWidth_x_test")
plt.ylabel("PatalLenth_y_test & PatalLenth_y_pred1")
plt.show()

plt.figure(figsize=(10,2))
plt.scatter(lr_test_p['PetalWidth_x_test'],lr_test_p['PatalLenth_y_test'], color="red",label='actual data')
plt.plot(lr_test_p['PetalWidth_x_test'],lr_test_p['PatalLenth_y_pred1'], color="blue",label='Predicted line ')
plt.legend()
plt.title("""Simple Linear Regression
PetalWidth_x_test vs PatalLenth_y_predition & PatalLenth_y_test""")
plt.xlabel("PetalWidth_x_test")
plt.ylabel("PatalLenth_y_test & PatalLenth_y_pred1")
plt.show()
plt.figure(figsize=(10,2))
plt.scatter(PetalLenth_y_allslr_p['PetalWidth_x_test'],PetalLenth_y_allslr_p['PatalLenth_y_test'], color="red",label='actual data')
plt.plot(PetalLenth_y_allslr_p['PetalWidth_x_test'],PetalLenth_y_allslr_p['PatalLenth_y_equa_lr'], color="blue",label='Predicted line of eqation of linear regresion')
plt.legend()
plt.title("""Equation of Linear Regression
PetalWidth_x_test vs PatalLenth_y_equation_linear Regression & PatalLenth_y_test""")
plt.xlabel("PetalWidth_x_test")
plt.ylabel("PatalLenth_y_test & PatalLenth_y_equation_lr")
plt.show()

# %% [markdown]
# ### Evaluation  of  Simple Linear Regression

# %% [markdown]
# ##### PatalLenght (y) & Patel width (x)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2

# %%
mabe = mae(y_test,y_pred1)
msqe =mse(y_test,y_pred1)
rmsqe= np.sqrt(mse(y_test,y_pred1))
r2sqe=r2(y_test,y_pred1)

# %%
print(f"Equation of Linear Regression's Mean Absolue Error is - {mabe} ")
print(f"Equation of Linear Regression's Mean square Error is - {msqe} ")
print(f"Equation of Linear Regression's Root Mean Square Error is - {rmsqe}")
print(f"Equation of Linear Regression's Root Score is - {r2sqe}")
# Out:
# Equation of Linear Regression's Mean Absolue Error is - 0.341072824314969
# Equation of Linear Regression's Mean square Error is - 0.19336991241089965
# Equation of Linear Regression's Root Mean Square Error is - 0.4397384590991555
# Equation of Linear Regression's Root Score is - 0.9417868758128862

# %% [markdown]
# ### Evaluation - Equation of Linear Regression

# %% [markdown]
# #### Petal Length (y) & Petal width (x)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2

# %%
mabe=mae(y_test,PetalLenth_y_equ_p)
msqe=mse(y_test,PetalLenth_y_equ_p)
rmsqe=np.sqrt(mse(y_test,PetalLenth_y_equ_p))
r2sqe=r2(y_test,PetalLenth_y_equ_p)

# %%
print(f"Equation of Linear Regression's Mean Absolue Error is - {mabe} ")
print(f"Equation of Linear Regression's Mean square Error is - {msqe} ")
print(f"Equation of Linear Regression's Root Mean Square Error is - {rmsqe}")
print(f"Equation of Linear Regression's Root Score is - {r2sqe}")
# Out:
# Equation of Linear Regression's Mean Absolue Error is - 0.341072824314969
# Equation of Linear Regression's Mean square Error is - 0.19336991241089965
# Equation of Linear Regression's Root Mean Square Error is - 0.4397384590991555
# Equation of Linear Regression's Root Score is - 0.9417868758128862
